# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


input_size = 784
# hidden_size = 500
num_classes = 10
num_epochs = 5
batch_size = 100
learning_rate = 0.001

# %%
import random
import numpy

def set_seed(seed: int, n_gpu: int):
    random.seed(seed)
    numpy.random.seed(seed)
    torch.manual_seed(seed)
    if n_gpu > 0:
        torch.cuda.manual_seed_all(seed)
        
set_seed(42, 1)

# %%
# MNIST dataset 
train_dataset = torchvision.datasets.MNIST(root="../data", 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root="../data", 
                                          train=False, 
                                          transform=transforms.ToTensor())

# загрузка данных
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)

# %%
# Определение архитектуры нейронной сети
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)  
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# %%
hidden_size_params=[600,500,400,300,200]
list_nn=[]

# %%
for hidden_size in hidden_size_params:
    model = NeuralNet(input_size, hidden_size, num_classes).to(device)
    model.train()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    total_step = len(train_loader)
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):  
        # перенос тензоров на определенный device
            images = images.reshape(-1, 28*28).to(device)
            labels = labels.to(device)
        
        # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)
        
        # Backpropagation and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
            if (i+1) % 100 == 0:
                print ('H_size={}, Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(hidden_size, epoch+1, num_epochs, i+1, total_step, loss.item()))
    list_nn.append(model)
# Out:
# H_size=600, Epoch [1/5], Step [100/600], Loss: 0.2492
# H_size=600, Epoch [1/5], Step [200/600], Loss: 0.3349
# H_size=600, Epoch [1/5], Step [300/600], Loss: 0.2123
# H_size=600, Epoch [1/5], Step [400/600], Loss: 0.2653
# H_size=600, Epoch [1/5], Step [500/600], Loss: 0.1345
# H_size=600, Epoch [1/5], Step [600/600], Loss: 0.0572
# H_size=600, Epoch [2/5], Step [100/600], Loss: 0.1054
# H_size=600, Epoch [2/5], Step [200/600], Loss: 0.1386
# H_size=600, Epoch [2/5], Step [300/600], Loss: 0.1436
# H_size=600, Epoch [2/5], Step [400/600], Loss: 0.0886
# H_size=600, Epoch [2/5], Step [500/600], Loss: 0.1222
# H_size=600, Epoch [2/5], Step [600/600], Loss: 0.0622
# H_size=600, Epoch [3/5], Step [100/600], Loss: 0.0373
# H_size=600, Epoch [3/5], Step [200/600], Loss: 0.0401
# H_size=600, Epoch [3/5], Step [300/600], Loss: 0.0217
# H_size=600, Epoch [3/5], Step [400/600], Loss: 0.0574
# H_size=600, Epoch [3/5], Step [500/600], Loss: 0.0869
# ...

# %%
for model in list_nn:
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.reshape(-1, 28*28).to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 97.97 %
# Accuracy of the network on the 10000 test images: 97.94 %
# Accuracy of the network on the 10000 test images: 97.82 %
# Accuracy of the network on the 10000 test images: 97.79 %
# Accuracy of the network on the 10000 test images: 97.54 %

# %%
class NeuralNet_new_ar(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet_new_ar, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.relu = nn.ReLU()
        self.b1d = nn.BatchNorm1d(hidden_size)
        self.fc2 = nn.Linear(hidden_size, int(hidden_size/10)) 
        self.relu2 = nn.ReLU()
        self.b1d2 = nn.BatchNorm1d(int(hidden_size/10))
        self.fc3 = nn.Linear(int(hidden_size/10), num_classes)  
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.b1d(out)
        out = self.fc2(out)
        out = self.relu2(out)
        out = self.b1d2(out)      
        out = self.fc3(out)
        return out

# %%
hidden_size_params=[600,500,400,300,200]
list_nn=[]

# %%
for hidden_size in hidden_size_params:
    model = NeuralNet_new_ar(input_size, hidden_size, num_classes).to(device)
    model.train()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    total_step = len(train_loader)
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):  
        # перенос тензоров на определенный device
            images = images.reshape(-1, 28*28).to(device)
            labels = labels.to(device)
        
        # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)
        
        # Backpropagation and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
            if (i+1) % 100 == 0:
                print ('H_size={}, Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(hidden_size, epoch+1, num_epochs, i+1, total_step, loss.item()))
    list_nn.append(model)
# Out:
# H_size=600, Epoch [1/5], Step [100/600], Loss: 0.4141
# H_size=600, Epoch [1/5], Step [200/600], Loss: 0.1255
# H_size=600, Epoch [1/5], Step [300/600], Loss: 0.2186
# H_size=600, Epoch [1/5], Step [400/600], Loss: 0.1782
# H_size=600, Epoch [1/5], Step [500/600], Loss: 0.1077
# H_size=600, Epoch [1/5], Step [600/600], Loss: 0.0823
# H_size=600, Epoch [2/5], Step [100/600], Loss: 0.0711
# H_size=600, Epoch [2/5], Step [200/600], Loss: 0.0671
# H_size=600, Epoch [2/5], Step [300/600], Loss: 0.0750
# H_size=600, Epoch [2/5], Step [400/600], Loss: 0.0380
# H_size=600, Epoch [2/5], Step [500/600], Loss: 0.0384
# H_size=600, Epoch [2/5], Step [600/600], Loss: 0.0926
# H_size=600, Epoch [3/5], Step [100/600], Loss: 0.0497
# H_size=600, Epoch [3/5], Step [200/600], Loss: 0.0363
# H_size=600, Epoch [3/5], Step [300/600], Loss: 0.0493
# H_size=600, Epoch [3/5], Step [400/600], Loss: 0.0735
# H_size=600, Epoch [3/5], Step [500/600], Loss: 0.0254
# ...

# %%
for model in list_nn:
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.reshape(-1, 28*28).to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 97.75 %
# Accuracy of the network on the 10000 test images: 97.74 %
# Accuracy of the network on the 10000 test images: 97.98 %
# Accuracy of the network on the 10000 test images: 97.54 %
# Accuracy of the network on the 10000 test images: 97.95 %

# %%
class NeuralNet_act(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes, activation):
        super(NeuralNet_act, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.relu = activation
        self.b1d = nn.BatchNorm1d(hidden_size)
        self.fc2 = nn.Linear(hidden_size, int(hidden_size/10)) 
        self.relu2 = activation
        self.b1d2 = nn.BatchNorm1d(int(hidden_size/10))
        self.fc3 = nn.Linear(int(hidden_size/10), num_classes)  
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.b1d(out)
        out = self.fc2(out)
        out = self.relu2(out)
        out = self.b1d2(out)      
        out = self.fc3(out)
        return out

# %%
activation=[nn.Tanh(), nn.ReLU(), nn.Sigmoid()]
hidden_size_params=[600,400,200]
list_nn=[]

# %%
for act in activation:
    for hidden_size in hidden_size_params:
        model = NeuralNet_act(input_size, hidden_size, num_classes, act).to(device)
        model.train()
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        total_step = len(train_loader)
        for epoch in range(num_epochs):
            for i, (images, labels) in enumerate(train_loader):  
            # перенос тензоров на определенный device
                images = images.reshape(-1, 28*28).to(device)
                labels = labels.to(device)

            # Forward pass
                outputs = model(images)
                loss = criterion(outputs, labels)

            # Backpropagation and optimization
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            if (i+1) % 100 == 0:
                print ('H_size={}, Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                       .format(hidden_size, epoch+1, num_epochs, i+1, total_step, loss.item()))
        list_nn.append(model)
# Out:
# H_size=600, Epoch [1/5], Step [600/600], Loss: 0.3640
# H_size=600, Epoch [2/5], Step [600/600], Loss: 0.0869
# H_size=600, Epoch [3/5], Step [600/600], Loss: 0.0530
# H_size=600, Epoch [4/5], Step [600/600], Loss: 0.0112
# H_size=600, Epoch [5/5], Step [600/600], Loss: 0.0544
# H_size=400, Epoch [1/5], Step [600/600], Loss: 0.1929
# H_size=400, Epoch [2/5], Step [600/600], Loss: 0.1621
# H_size=400, Epoch [3/5], Step [600/600], Loss: 0.1228
# H_size=400, Epoch [4/5], Step [600/600], Loss: 0.0147
# H_size=400, Epoch [5/5], Step [600/600], Loss: 0.0512
# H_size=200, Epoch [1/5], Step [600/600], Loss: 0.0997
# H_size=200, Epoch [2/5], Step [600/600], Loss: 0.1149
# H_size=200, Epoch [3/5], Step [600/600], Loss: 0.1129
# H_size=200, Epoch [4/5], Step [600/600], Loss: 0.0811
# H_size=200, Epoch [5/5], Step [600/600], Loss: 0.0568
# H_size=600, Epoch [1/5], Step [600/600], Loss: 0.1580
# H_size=600, Epoch [2/5], Step [600/600], Loss: 0.1749
# ...

# %%
for model in list_nn:
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.reshape(-1, 28*28).to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 97.82 %
# Accuracy of the network on the 10000 test images: 97.9 %
# Accuracy of the network on the 10000 test images: 97.68 %
# Accuracy of the network on the 10000 test images: 98.02 %
# Accuracy of the network on the 10000 test images: 97.9 %
# Accuracy of the network on the 10000 test images: 97.76 %
# Accuracy of the network on the 10000 test images: 97.39 %
# Accuracy of the network on the 10000 test images: 97.25 %
# Accuracy of the network on the 10000 test images: 97.12 %

# %%
def train(model, optimizer):
    model.train()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    total_step = len(train_loader)
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):  
            # перенос тензоров на определенный device
            images = images.reshape(-1, 28*28).to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)

            # Backpropagation and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if (i+1) % 100 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                    .format(epoch+1, num_epochs, i+1, total_step, loss.item()))

# %%
def test(model):
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.reshape(-1, 28*28).to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
    return correct / total

# %%
import torch.nn.functional as F

from ray import tune
from ray.tune.schedulers import ASHAScheduler

# %%
def train_mnist(config):
    hidden_size=600
    act=nn.ReLU()
    model = NeuralNet_act(input_size, hidden_size, num_classes, act).to(device)
    optimizer = optim.SGD(
        model.parameters(), lr=config["lr"], momentum=config["momentum"])
    for i in range(10):
        train(model, optimizer)
        acc = test(model)

        # Send the current training result back to Tune
        tune.report(mean_accuracy=acc)

        if i % 5 == 0:
            # This saves the model to the trial directory
            torch.save(model.state_dict(), "model.pth")

# %%
import numpy as np
import torch.optim as optim

# %%
search_space = {
    "lr": tune.sample_from(lambda spec: 10**(-10 * np.random.rand())),
    "momentum": tune.uniform(0.1, 0.9)
}

# %%
analysis = tune.run(train_mnist, config=search_space)
# Out:
# 2021-01-10 18:49:29,027	WARNING tune.py:409 -- Tune detects GPUs, but no trials are using GPUs. To enable trials to use GPUs, set tune.run(resources_per_trial={'gpu': 1}...) which allows Tune to expose 1 GPU to each trial. You can also override `Trainable.default_resource_request` if using the Trainable API.
# 2021-01-10 18:49:34,220	WARNING worker.py:1034 -- Warning: The actor ImplicitFunc has size 55447626 when pickled. It will be stored in Redis, which could cause memory issues. This may mean that its definition uses a large array or other object.
# 2021-01-10 18:49:34,430	WARNING util.py:142 -- The `start_trial` operation took 3.715 s, which may be a performance bottleneck.
# == Status ==<br>Memory usage on this node: 9.8/15.9 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1/4 CPUs, 0/1 GPUs, 0.0/4.39 GiB heap, 0.0/1.51 GiB objects<br>Result logdir: C:\Users\Lost\ray_results\train_mnist_2021-01-10_18-49-26<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# ...

# %%
from hyperopt import hp
from ray.tune.suggest.hyperopt import HyperOptSearch

space = {
    "lr": hp.loguniform("lr", 1e-10, 0.1),
    "momentum": hp.uniform("momentum", 0.1, 0.9),
}

hyperopt_search = HyperOptSearch(space, metric="mean_accuracy", mode="max")

# %%
analysis = tune.run(train_mnist, num_samples=10, search_alg=hyperopt_search)
# Out:
# 2021-01-10 19:13:12,792	WARNING tune.py:409 -- Tune detects GPUs, but no trials are using GPUs. To enable trials to use GPUs, set tune.run(resources_per_trial={'gpu': 1}...) which allows Tune to expose 1 GPU to each trial. You can also override `Trainable.default_resource_request` if using the Trainable API.
# 2021-01-10 19:13:19,368	WARNING worker.py:1034 -- Warning: The actor ImplicitFunc has size 55447626 when pickled. It will be stored in Redis, which could cause memory issues. This may mean that its definition uses a large array or other object.
# 2021-01-10 19:13:19,515	WARNING util.py:142 -- The `start_trial` operation took 4.583 s, which may be a performance bottleneck.
# == Status ==<br>Memory usage on this node: 10.4/15.9 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1/4 CPUs, 0/1 GPUs, 0.0/4.39 GiB heap, 0.0/1.51 GiB objects<br>Result logdir: C:\Users\Lost\ray_results\train_mnist_2021-01-10_19-13-10<br>Number of trials: 1/10 (1 RUNNING)<br><table>
# ...

# %%
import os

df = analysis.results_df
logdir = analysis.get_best_logdir("mean_accuracy", mode="max")
state_dict = torch.load("model.pth")
# Out:
# 2021-01-10 20:45:32,510	WARNING experiment_analysis.py:576 -- Could not find best trial. Did you pass the correct `metric` parameter?

# %%
hidden_size=600
act=nn.ReLU()
model = NeuralNet_act(input_size, hidden_size, num_classes, act).to(device)

# %%
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
test(model)
# Out:
# Accuracy of the network on the 10000 test images: 98.22 %
